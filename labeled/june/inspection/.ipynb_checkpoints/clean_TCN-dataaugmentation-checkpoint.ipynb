# %%
# ====================================================================
# 0. imports & reproducibility
# ====================================================================
import pandas as pd, numpy as np, tensorflow as tf, matplotlib.pyplot as plt
from tcn import TCN
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from pathlib import Path
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adamax, Nadam, Adadelta

rng = np.random.default_rng(72)
tf.keras.utils.set_random_seed(72)
tf.debugging.enable_check_numerics()          # crash early on NaN/Inf
# Out:
# INFO:tensorflow:Enabled check-numerics callback in thread MainThread

# %%
# ------------------------------------------------------------------
# files you want to merge  (add as many as you like)
# ------------------------------------------------------------------
FILES = [
    "previous_dv0_withoutstraw_sipCAdded.xlsx", 
    "dv0_withoutstraw_sipCAdded.xlsx",
                       # ← put your second file name here
    # "third_file.xlsx",
]

# %%
# ------------------------------------------------------------------
# read & re-index
# ------------------------------------------------------------------
dfs          = []
next_offset  = 0          # keeps track of the next free Participant_ID

for fp in FILES:
    fp = Path(fp)
    df = pd.read_excel(fp)

    # current file's min/max before shifting (optional print for sanity)
    old_min, old_max = df["Participant_ID"].min(), df["Participant_ID"].max()
    print(f"{fp.name}: original IDs {old_min} … {old_max}")

    # shift IDs so they don't collide with previous files
    df["Participant_ID"] += next_offset

    # update next_offset for the *next* file
    next_offset = df["Participant_ID"].max() + 1

    # done
    dfs.append(df)
    print(f"   shifted to {df['Participant_ID'].min()} … {df['Participant_ID'].max()}")
# Out:
# previous_dv0_withoutstraw_sipCAdded.xlsx: original IDs 6 … 62
#    shifted to 6 … 62
# dv0_withoutstraw_sipCAdded.xlsx: original IDs 1 … 14
#    shifted to 64 … 77

# %%
# ------------------------------------------------------------------
# combined DataFrame
# ------------------------------------------------------------------
df_all = pd.concat(dfs, ignore_index=True)
print("\nMerged dataframe shape:", df_all.shape)
print("Global Participant_ID range:", df_all["Participant_ID"].min(),
      "…", df_all["Participant_ID"].max())
# Out:
# Merged dataframe shape: (99996, 82)
# Global Participant_ID range: 6 … 77

# %%
df_all
# Out:
#        Unnamed: 0            Time  Zone_0  Zone_1  Zone_2  Zone_3  Zone_4  \
# 0               0   1747823631000    2162    2155    3941     362     324
# 1               1   1747823631200    2162    2155    3941     362     324
# 2               2   1747823631400    2162    2155    3941     362     324
# 3               3   1747823631600    2162    2155    3941     362     324
# 4               4   1747823631800    2162    2155    3941     362     324
# ...           ...             ...     ...     ...     ...     ...     ...
# 99991       20621   1750719007400    1647    1625    1610    1610    1592
# 99992       20622   1750719007600    1637    1611    1592    1596    1570
# 99993       20623   1750719007800    1607    1607    1592    1595    1568
# 99994       20624   1750719008000    1602    1593    1586    1585    1568
# 99995       20625  17507188911000    1607    1593    1594    1585    1568
#
#        Zone_5  Zone_6  Zone_7  ...  Container_Weight   drink  temp  prev  \
# 0         342    3605    2071  ...              19.8  coke-r     c     0
# 1         342    3605    2071  ...              19.8  coke-r     c     0
# 2         342    3605    2071  ...              19.8  coke-r     c     0
# 3         342    3605    2071  ...              19.8  coke-r     c     0
# 4         342    3605    2071  ...              19.8  coke-r     c     0
# ...       ...     ...     ...  ...               ...     ...   ...   ...
# 99991    1569    1580    1569  ...               7.7   water     n     0
# 99992    1569    1575    1569  ...               7.7   water     n     0
# 99993    1567    1560    1566  ...               7.7   water     n     0
# 99994    1562    1560    1560  ...               7.7   water     n     0
# 99995    1562    1560    1560  ...               7.7   water     n     0
#
#        next  sip_start  sip_end  sip_id   dV  TOTAL_SIP_TIME
# 0         0      False    False       0  0.0               0
# 1         0      False    False       0  0.0               0
# 2         0      False    False       0  0.0               0
# 3         0      False    False       0  0.0               0
# 4         0      False    False       0  0.0               0
# ...     ...        ...      ...     ...  ...             ...
# 99991     0      False    False       5  0.0               0
# 99992     0      False    False       5  0.0               0
# 99993     0      False    False       5  0.0               0
# 99994     0      False    False       5  0.0               0
# 99995     0      False    False       5  0.0               0
#
# [99996 rows x 82 columns]

# %%
df = df_all

# %%
# print("Label stats  (raw, before scaling)")
# print("  min :", y.min())
# print("  #zeros :", (y == 0).sum())
# print("  any negative? ", (y < 0).any())

# %%
# --------------------------------------------------------------------
# user settings
# --------------------------------------------------------------------

BATCH      = 8                                   # 1 = ragged, >1 = padded

# %%
# # ====================================================================
# # 1. load data  ➜  X(list of (T,64)), y(array)   – SKIP zero-volume sips
# # ====================================================================
# df = df[df["Label"] == 1]                        # keep only annotated frames

# feature_cols = df.columns[2:66]
# seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# X, y = [], []
# skip_count = 0

# for _, g in df.groupby(seq_keys, sort=False):
#     dV = float(g[label_col].iloc[0])
#     if dV == 0.0:                                # ← drop empty sip
#         skip_count += 1
#         continue
#     X.append(g[feature_cols].to_numpy(np.float32))   # (T,64)
#     y.append(dV)

# y = np.asarray(y, np.float32)
# X = np.array(X, dtype=object)   # each element is still a (T,64) array
# print(f"Total sips kept : {len(X)}")
# print(f"Zero-volume skipped : {skip_count}")
# print("Label stats  → min:", y.min(), "max:", y.max())

# %%
# # ====================================================================
# # 1. load data  ➜  X(list of (T,64)), y(array) – SKIP zero-volume sips – APPLY AUGMENTATION
# # ====================================================================

# df = df[df["Label"] == 1]                        # keep only annotated frames

# feature_cols = df.columns[2:66]
# seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# # --- Augmentation Functions ---
# def add_gaussian_noise(sip, std_dev=0.01):
#     """Add Gaussian noise to the sip (T, 64)."""
#     noise = np.random.normal(0, std_dev, sip.shape)
#     return sip + noise

# def flip_horizontal(sip):
#     """Flip 8x8 frames horizontally for all time steps in sip (T, 64)."""
#     flipped = []
#     for frame in sip:
#         frame_8x8 = frame.reshape(8, 8)
#         flipped_frame = np.fliplr(frame_8x8).flatten()
#         flipped.append(flipped_frame)
#     return np.array(flipped, dtype=np.float32)

# # --- You control this threshold: sips longer than this will be augmented
# AUGMENT_IF_LONGER_THAN = 15  # You can change this

# # --- Main data list
# X, y = [], []
# skip_count = 0

# for _, g in df.groupby(seq_keys, sort=False):
#     dV = float(g[label_col].iloc[0])
#     if dV == 0.0:
#         skip_count += 1
#         continue

#     sip_frames = g[feature_cols].to_numpy(np.float32)  # shape (T, 64)
#     T = len(sip_frames)

#     X.append(sip_frames)
#     y.append(dV)

#     # Augment only if sip is long
#     if T > AUGMENT_IF_LONGER_THAN:
#         # 1. Add Gaussian noise
#         noisy_sip = add_gaussian_noise(sip_frames)
#         X.append(noisy_sip)
#         y.append(dV)

#         # 2. Flip horizontally
#         flipped_sip = flip_horizontal(sip_frames)
#         X.append(flipped_sip)
#         y.append(dV)
# X = np.array(X, dtype=object)   # each sip is still (T, 64)
# y = np.array(y, dtype=np.float32)

# print(f"Total sips kept (including augmented): {len(X)}")
# print(f"Zero-volume skipped : {skip_count}")
# print("Label stats  → min:", min(y), "max:", max(y))

# %%
# ====================================================================
# 1. load data  ➜  X(list of (T,64)), y(array) – SKIP zero-volume sips – APPLY AUGMENTATION
# ====================================================================


df = df[df["Label"] == 1]  # keep only annotated frames

feature_cols = df.columns[2:66]
seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# --- Augmentation Functions ---
def add_gaussian_noise(sip, std_dev=40):
    """Add Gaussian noise to the sip (T, 64)."""
    noise = np.random.normal(0, std_dev, sip.shape)
    return sip + noise

def flip_horizontal(sip):
    """Flip 8x8 frames horizontally for all time steps in sip (T, 64)."""
    flipped = []
    for frame in sip:
        frame_8x8 = frame.reshape(8, 8)
        flipped_frame = np.fliplr(frame_8x8).flatten()
        flipped.append(flipped_frame)
    return np.array(flipped, dtype=np.float32)

# --- Thresholds you control
AUGMENT_IF_LONGER_THAN = 15           # Regular augmentation if T > this
MORE_AUGMENT_IF_LONGER_THAN = 20      # Extra augmentation if T > this
NUM_EXTRA_NOISY_COPIES = 5            # Number of additional noise versions for long sips
NUM_EXTRA_NOISY_COPIES_2 =3
MORE_AUGMENT_IF_LONGER_THAN_2= 34
# --- Main data list
X, y = [], []
skip_count = 0

for _, g in df.groupby(seq_keys, sort=False):
    dV = float(g[label_col].iloc[0])
    if dV == 0.0:
        skip_count += 1
        continue

    sip_frames = g[feature_cols].to_numpy(np.float32)  # shape (T, 64)
    T = len(sip_frames)

    # Original sip
    X.append(sip_frames)
    y.append(dV)

    # Moderate-length sip → 1 noise + 1 flip
    if T > AUGMENT_IF_LONGER_THAN:
        noisy_sip = add_gaussian_noise(sip_frames)
        X.append(noisy_sip)
        y.append(dV)

        flipped_sip = flip_horizontal(sip_frames)
        X.append(flipped_sip)
        y.append(dV)

    # Extra-long sip → multiple noise augmentations
    if T > MORE_AUGMENT_IF_LONGER_THAN:
        for _ in range(NUM_EXTRA_NOISY_COPIES):
            noisy_version = add_gaussian_noise(sip_frames)
            X.append(noisy_version)
            y.append(dV)
    if T > MORE_AUGMENT_IF_LONGER_THAN_2:
        for _ in range(NUM_EXTRA_NOISY_COPIES_2):
            noisy_version = add_gaussian_noise(sip_frames)
            X.append(noisy_version)
            y.append(dV)        

# Final conversion to array
X = np.array(X, dtype=object)   # each sip is still (T, 64)
y = np.array(y, dtype=np.float32)

print(f"Total sips kept (including augmented): {len(X)}")
print(f"Zero-volume skipped : {skip_count}")
print("Label stats  → min:", min(y), "max:", max(y))
# Out:
# Total sips kept (including augmented): 1338
# Zero-volume skipped : 2
# Label stats  → min: 1.4691479 max: 160.2

# %%
import matplotlib.pyplot as plt

# Get time step lengths for all sips
time_steps = [sip.shape[0] for sip in X]  # X is your final data after augmentation

# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(time_steps, bins=30, alpha=0.7, color='blue')
plt.title('Histogram of Time Steps After Augmentation')
plt.xlabel('Number of Time Steps')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
X[:1]
# Out:
# array([array([[2487.,  165.,  348., ...,  364.,  330., 1817.],
#               [2487.,  165.,  348., ...,  364.,  330., 1817.],
#               [ 265.,  200.,  234., ...,  364.,  352., 1817.],
#               ...,
#               [ 304., 2267., 2300., ...,  331., 1449., 1140.],
#               [ 299., 2267., 2300., ...,  352.,  352., 1151.],
#               [ 295., 2280., 2300., ...,  352., 1449., 1151.]], dtype=float32)],
#       dtype=object)

# %%
print(type(X))          # <class 'numpy.ndarray'>
print(X.shape)          # (number,)

print(type(X[0]))       # <class 'numpy.ndarray'>
print(X[0].shape)       # (rows, columns)
# Out:
# <class 'numpy.ndarray'>
# (1338,)
# <class 'numpy.ndarray'>
# (26, 64)

# %%
# ====================================================================
# 2. shuffle whole sips ➜ 80 / 20 split
# ====================================================================
idx = rng.permutation(len(X))
split1 = int(.64 * len(X))          # 64 % train
split2 = int(.80 * len(X))          # next 16 % val
X_train, y_train = X[idx[:split1]], y[idx[:split1]]
X_val,   y_val   = X[idx[split1:split2]], y[idx[split1:split2]]
X_test,  y_test  = X[idx[split2:]], y[idx[split2:]]
print(f"Train {len(X_train)} Val {len(X_val)}  Test {len(X_test)}")
# y_train_s = np.log1p(y_train)        # log1p for numerical safety
# y_val_s   = np.log1p(y_val)
# y_test_s  = np.log1p(y_test)
# Out:
# Train 856 Val 214  Test 268

# %%
# X_train

# %%
# y_train

# %%
# ====================================================================
# 3. column-wise z-score normalisation (fit on training only)
# ====================================================================
mat_train = np.vstack(X_train)          # ⬅ only TRAIN data
mean64 = mat_train.mean(0, keepdims=True)
std64  = mat_train.std(0,  keepdims=True) + 1e-8

norm = lambda seq: (seq - mean64) / std64
X_train = [norm(s) for s in X_train]
X_val   = [norm(s) for s in X_val]
X_test  = [norm(s) for s in X_test]

# # label scaling
# y_max   = y_train.max() or 1.
# y_train_s = y_train / y_max
# y_val_s   = y_val   / y_max
# y_test_s  = y_test  / y_max
y_train_s = y_train 
y_val_s   = y_val   
y_test_s  = y_test

# %%
# X_train

# %%
# ====================================================================
# 4. tf.data pipelines
# ====================================================================
def generator(xs, ys):
    for x, y in zip(xs, ys):
        yield x, y

output_sig = (
    tf.TensorSpec((None, 64), tf.float32),
    tf.TensorSpec((),          tf.float32)
)

def make_ds(xs, ys, shuffle=True):
    ds = tf.data.Dataset.from_generator(lambda: generator(xs, ys),
                                        output_signature=output_sig)
    if shuffle:
        ds = ds.shuffle(len(xs), seed=42)
    if BATCH == 1:
        return ds.repeat().batch(1)              # ragged
    return ds.repeat().padded_batch(             # padded
        BATCH,
        padded_shapes=([None, 64], []),
        padding_values=(0.0, 0.0)
    )

train_ds = make_ds(X_train, y_train_s, shuffle=True)
val_ds   = make_ds(X_val,   y_val_s,   shuffle=False)
test_ds  = make_ds(X_test,  y_test_s,  shuffle=False)

# %%
train_ds
# Out:
# <_PaddedBatchDataset element_spec=(TensorSpec(shape=(None, None, 64), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
# for batch in train_ds.take(1):
#     x_batch, y_batch = batch
#     print("x_batch shape:", x_batch.shape)
#     print("y_batch shape:", y_batch.shape)
#     print("x_batch:", x_batch.numpy())
#     print("y_batch:", y_batch.numpy())

# %%
# ====================================================================
# 5. model  – TCN ➜ Dense(1, softplus) keeps output ≥ 0
# ====================================================================
inp = tf.keras.Input(shape=(None, 64))
x = TCN(nb_filters=128,
        kernel_size=3,
        dilations=[1,2,4,8,16,32,64],   # ~64-time-step field
        dropout_rate=0.1,
        return_sequences=False)(inp)
out = tf.keras.layers.Dense(1)(x)          # ← LINEAR output
model = tf.keras.Model(inp, out)

model.compile(
    optimizer=Adagrad(learning_rate=0.01),
    loss="mae"                             # MAE is more robust
)
model.summary()

steps_per_epoch = len(X_train) // BATCH + (len(X_train) % BATCH > 0)
val_steps       = len(X_val)   // BATCH + (len(X_val)   % BATCH > 0)
# weights = (y_train / y_train.max()) ** 0.5  
cb = tf.keras.callbacks.EarlyStopping(
         monitor='val_loss', patience=50, restore_best_weights=True)
model.fit(
    train_ds,
    epochs=200,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,        # ⬅ use VALIDATION set
    validation_steps=val_steps,
    verbose=1,
    # sample_weight=weights,
    callbacks=[cb]
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tcn (TCN)                       │ (None, 128)            │       673,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 673,793 (2.57 MB)
#  Trainable params: 673,793 (2.57 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 68.0914 - val_loss: 18.9789
# Epoch 2/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 18.1381 - val_loss: 18.9095
# Epoch 3/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 14.0734 - val_loss: 16.1534
# Epoch 4/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 13.0988 - val_loss: 14.9674
# Epoch 5/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.7332 - val_loss: 14.6132
# Epoch 6/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.7361 - val_loss: 13.9530
# Epoch 7/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.9130 - val_loss: 13.7959
# Epoch 8/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.2644 - val_loss: 15.2142
# Epoch 9/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 9.8786 - val_loss: 14.7831
# Epoch 10/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.8844 - val_loss: 14.5943
# Epoch 11/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.7887 - val_loss: 13.8729
# Epoch 12/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.4408 - val_loss: 12.8994
# Epoch 13/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.7788 - val_loss: 13.4579
# Epoch 14/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.9912 - val_loss: 14.9280
# Epoch 15/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 7.9082 - val_loss: 10.5440
# Epoch 16/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.5839 - val_loss: 11.7928
# Epoch 17/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 7.9006 - val_loss: 11.5632
# Epoch 18/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 7.6888 - val_loss: 12.3666
# Epoch 19/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.5785 - val_loss: 11.9205
# Epoch 20/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.1004 - val_loss: 10.3493
# Epoch 21/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 7.4324 - val_loss: 10.8074
# Epoch 22/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.2951 - val_loss: 10.0874
# Epoch 23/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.1202 - val_loss: 11.6380
# Epoch 24/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.0641 - val_loss: 12.4360
# Epoch 25/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.0008 - val_loss: 10.9561
# Epoch 26/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 6.8670 - val_loss: 9.2893
# Epoch 27/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 6.1038 - val_loss: 10.1043
# Epoch 28/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 6.5049 - val_loss: 12.4618
# Epoch 29/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 5.9392 - val_loss: 9.3273
# Epoch 30/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 6.3481 - val_loss: 9.1221
# Epoch 31/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 6.4129 - val_loss: 9.5850
# Epoch 32/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 6.2249 - val_loss: 10.6751
# Epoch 33/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 6.1695 - val_loss: 9.9087
# Epoch 34/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 5.5189 - val_loss: 10.2550
# Epoch 35/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 5.5953 - val_loss: 13.8829
# Epoch 36/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 5.5402 - val_loss: 11.8818
# Epoch 37/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.2905 - val_loss: 8.6316
# Epoch 38/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 5.3925 - val_loss: 9.4184
# Epoch 39/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 5.4065 - val_loss: 8.2650
# Epoch 40/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 5.4792 - val_loss: 10.7653
# Epoch 41/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 5.5947 - val_loss: 9.9180
# Epoch 42/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 5.0921 - val_loss: 10.5175
# Epoch 43/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 5.1706 - val_loss: 10.0459
# Epoch 44/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 5.5280 - val_loss: 11.0354
# Epoch 45/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 5.0471 - val_loss: 9.1950
# Epoch 46/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 4.9223 - val_loss: 10.9069
# Epoch 47/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 4.9164 - val_loss: 10.1484
# Epoch 48/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 4.9990 - val_loss: 9.9976
# Epoch 49/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 5.6492 - val_loss: 10.4510
# Epoch 50/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 4.9950 - val_loss: 12.0805
# Epoch 51/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 4.8594 - val_loss: 9.9121
# Epoch 52/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.5571 - val_loss: 8.9041
# Epoch 53/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.1894 - val_loss: 10.2466
# Epoch 54/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.6551 - val_loss: 10.5119
# Epoch 55/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.7170 - val_loss: 9.1108
# Epoch 56/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.4565 - val_loss: 9.0344
# Epoch 57/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.6201 - val_loss: 10.0181
# Epoch 58/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.4153 - val_loss: 10.2917
# Epoch 59/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.3803 - val_loss: 8.8476
# Epoch 60/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 4.1055 - val_loss: 11.6019
# Epoch 61/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.6560 - val_loss: 8.5968
# Epoch 62/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.4316 - val_loss: 8.7133
# Epoch 63/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 3.9057 - val_loss: 9.0680
# Epoch 64/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.4706 - val_loss: 9.2537
# Epoch 65/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.4461 - val_loss: 8.1897
# Epoch 66/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 4.6667 - val_loss: 9.2579
# Epoch 67/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.2980 - val_loss: 9.2821
# Epoch 68/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.1396 - val_loss: 9.6747
# Epoch 69/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.4931 - val_loss: 11.0089
# Epoch 70/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.9499 - val_loss: 8.3204
# Epoch 71/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.2508 - val_loss: 9.9050
# Epoch 72/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.9830 - val_loss: 8.4358
# Epoch 73/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.5056 - val_loss: 9.6120
# Epoch 74/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.8713 - val_loss: 7.9887
# Epoch 75/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.0614 - val_loss: 8.6300
# Epoch 76/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.8926 - val_loss: 8.9578
# Epoch 77/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.7699 - val_loss: 9.7236
# Epoch 78/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.5951 - val_loss: 9.6613
# Epoch 79/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.9792 - val_loss: 10.2485
# Epoch 80/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 3.7919 - val_loss: 9.5776
# Epoch 81/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.9262 - val_loss: 10.3195
# Epoch 82/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.0232 - val_loss: 10.0338
# Epoch 83/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 3.6765 - val_loss: 11.1404
# Epoch 84/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.5686 - val_loss: 9.3935
# Epoch 85/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 4.3099 - val_loss: 7.4770
# Epoch 86/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 4.0044 - val_loss: 9.6062
# Epoch 87/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.8238 - val_loss: 9.1250
# Epoch 88/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.8568 - val_loss: 9.6802
# Epoch 89/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.6792 - val_loss: 9.5592
# Epoch 90/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.7098 - val_loss: 10.6409
# Epoch 91/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.4898 - val_loss: 10.2039
# Epoch 92/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.7741 - val_loss: 9.3805
# Epoch 93/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 3.3634 - val_loss: 10.0422
# Epoch 94/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.1002 - val_loss: 9.6055
# Epoch 95/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 3.6094 - val_loss: 8.9194
# Epoch 96/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 3.8559 - val_loss: 9.0201
# Epoch 97/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.3928 - val_loss: 9.7705
# Epoch 98/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.6523 - val_loss: 8.9076
# Epoch 99/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.4567 - val_loss: 7.8679
# Epoch 100/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.6965 - val_loss: 8.5517
# Epoch 101/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.7172 - val_loss: 9.1401
# Epoch 102/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.4077 - val_loss: 9.2805
# Epoch 103/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.7920 - val_loss: 10.2924
# Epoch 104/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.4013 - val_loss: 7.7566
# Epoch 105/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.4369 - val_loss: 9.6821
# Epoch 106/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.1984 - val_loss: 8.8613
# Epoch 107/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.8284 - val_loss: 8.8620
# Epoch 108/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.5238 - val_loss: 9.1820
# Epoch 109/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.6514 - val_loss: 10.0149
# Epoch 110/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.3256 - val_loss: 8.9593
# Epoch 111/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.5423 - val_loss: 8.3367
# Epoch 112/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.2483 - val_loss: 9.2027
# Epoch 113/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.3063 - val_loss: 8.1659
# Epoch 114/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.4682 - val_loss: 9.2544
# Epoch 115/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.2308 - val_loss: 10.1067
# Epoch 116/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.4786 - val_loss: 9.6672
# Epoch 117/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.3694 - val_loss: 9.1931
# Epoch 118/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.4073 - val_loss: 9.2150
# Epoch 119/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.1598 - val_loss: 9.8385
# Epoch 120/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 3.5903 - val_loss: 8.8028
# Epoch 121/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.3716 - val_loss: 8.2782
# Epoch 122/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 3.1302 - val_loss: 7.6070
# Epoch 123/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.3105 - val_loss: 9.6886
# Epoch 124/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.2826 - val_loss: 9.9365
# Epoch 125/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.2393 - val_loss: 8.2582
# Epoch 126/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.2057 - val_loss: 8.8716
# Epoch 127/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.2029 - val_loss: 9.6047
# Epoch 128/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.2783 - val_loss: 9.8053
# Epoch 129/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.1592 - val_loss: 9.0894
# Epoch 130/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.0906 - val_loss: 9.8026
# Epoch 131/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 3.1020 - val_loss: 8.9213
# Epoch 132/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.2830 - val_loss: 10.1451
# Epoch 133/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.0475 - val_loss: 8.7174
# Epoch 134/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.0513 - val_loss: 8.8787
# Epoch 135/200
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.1882 - val_loss: 9.9731

# %%
# ====================================================================
# 6. inference on test set (un-scale predictions)
# ====================================================================
y_pred_s = np.array([model.predict(seq[None, ...], verbose=0)[0, 0]
                     for seq in X_test])
# inverse transform after prediction
# y_pred_s = np.expm1(y_pred_s)
# y_pred   = y_pred_s * y_max
y_pred = y_pred_s
y_mean, y_std = y_train.mean(), y_train.std()
y_train_s = (y_train - y_mean) / y_std
# ...
# y_pred = y_pred_s * y_std + y_mean       # undo scaling

# %%
# ====================================================================
# 7. evaluation
# ====================================================================
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2   = r2_score(y_test, y_pred)

non_zero = y_test != 0
rmspe = (np.sqrt(np.mean(((y_test[non_zero]-y_pred[non_zero]) /
                          y_test[non_zero])**2))*100
         if non_zero.any() else np.nan)

print(f"\nEvaluation on {len(y_test)} test sips")
print(f"  MSE   : {mse:.4f}")
print(f"  RMSE  : {rmse:.4f}")
print(f"  R²    : {r2:.4f}")
print(f"  RMSPE : {rmspe:.2f}%")

comparison_df = pd.DataFrame({"Actual dV": y_test, "Predicted dV": y_pred})
print("\nFirst 50 predictions:")
print(comparison_df.head(50))
# Out:
# Evaluation on 268 test sips
#   MSE   : 125.1834
#   RMSE  : 11.1885
#   R²    : 0.8842
#   RMSPE : 48.98%
#
# First 50 predictions:
#      Actual dV  Predicted dV
# 0    74.285713     75.328598
# 1    36.238983     38.147499
# 2    26.052889     27.065969
# 3     6.072478     19.481300
# 4    24.100000     16.073740
# 5    16.571428     16.932257
# 6    20.000000     30.686129
# 7    12.996032     13.099351
# 8    19.588638     33.952049
# 9    23.100000     21.370358
# 10   13.712047     19.767775
# 11   37.599998     10.106441
# 12   55.299999     44.510223
# 13   10.912699     23.220110
# 14   18.650793     10.740722
# 15   27.326151     18.212519
# 16   59.523811     63.347633
# 17   22.624878     13.456934
# 18    5.320197      4.377516
# 19   24.387856     27.190887
# 20   60.000000     63.223053
# 21   23.809525     13.583284
# 22   97.943192     99.374748
# 23   12.500000     12.451083
# 24   30.852106     22.766085
# 25   59.523811     77.497063
# 26   53.200001     33.963455
# 27   59.523811     64.729721
# 28   35.200001     25.574173
# 29    6.944445     15.506246
# 30   95.238098     91.280968
# 31   20.337301     20.181484
# 32   73.500000     69.989380
# 33   39.500000     39.052246
# 34  100.000000     97.910271
# 35   79.365082     79.024170
# 36  131.699997    130.404388
# 37   58.000000     34.996986
# 38   17.100000     16.022993
# 39    9.960552     13.862863
# 40  100.000000     94.584038
# 41   78.354553     76.306786
# 42    5.320197      4.364889
# 43   30.190475     23.227854
# 44   99.206352     80.619240
# 45   14.186508     14.689777
# 46   13.428572     13.274693
# 47   24.387856     27.397638
# 48    5.221675      5.405210
# 49    6.646825      6.768214

# %%
# ====================================================================
# 8. scatter plot
# ====================================================================
plt.figure(figsize=(7, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
lims = [0, max(y_test.max(), y_pred.max()) * 1.05]
plt.plot(lims, lims, "r--")
plt.xlim(lims); plt.ylim(lims)
plt.xlabel("Actual dV"); plt.ylabel("Predicted dV")
plt.title("TCN – Actual vs. Predicted Drinking Volume")
plt.grid(True); plt.tight_layout(); plt.show()

# %%
# print("First 5 log targets  :", y_train_s[:5])
# print("First 5 raw targets  :", y_train[:5])

# # after one epoch
# raw_pred = np.expm1(model.predict(X_val[:3])[...,0])
# print("First 3 un-scaled predictions:", raw_pred)

# %%
print("train  min / max (ml):", y_train.min(), y_train.max())
print("train_s min / max (log):", y_train_s.min(), y_train_s.max())

# quick expectation check:  ln(1+160) ≈ 5.08
#                           ln(1+  5) ≈ 1.79
# Out:
# train  min / max (ml): 1.7629775 160.2
# train_s min / max (log): -1.3521234 3.7237537
