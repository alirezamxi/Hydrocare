# %%
# ====================================================================
# 0. imports & reproducibility
# ====================================================================
import pandas as pd, numpy as np, tensorflow as tf, matplotlib.pyplot as plt
from tcn import TCN
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from pathlib import Path
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adamax, Nadam, Adadelta
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Concatenate
from tcn import TCN
rng = np.random.default_rng(72)
tf.keras.utils.set_random_seed(72)
tf.debugging.enable_check_numerics()          # crash early on NaN/Inf
# Out:
# INFO:tensorflow:Enabled check-numerics callback in thread MainThread

# %%
# ------------------------------------------------------------------
# files you want to merge  (add as many as you like)
# ------------------------------------------------------------------
FILES = [
    "previous_dv0_withoutstraw_sipCAdded.xlsx", 
    "dv0_withoutstraw_sipCAdded.xlsx",
                       # ← put your second file name here
    # "third_file.xlsx",
]

# %%
# ------------------------------------------------------------------
# read & re-index
# ------------------------------------------------------------------
dfs          = []
next_offset  = 0          # keeps track of the next free Participant_ID

for fp in FILES:
    fp = Path(fp)
    df = pd.read_excel(fp)

    # current file's min/max before shifting (optional print for sanity)
    old_min, old_max = df["Participant_ID"].min(), df["Participant_ID"].max()
    print(f"{fp.name}: original IDs {old_min} … {old_max}")

    # shift IDs so they don't collide with previous files
    df["Participant_ID"] += next_offset

    # update next_offset for the *next* file
    next_offset = df["Participant_ID"].max() + 1

    # done
    dfs.append(df)
    print(f"   shifted to {df['Participant_ID'].min()} … {df['Participant_ID'].max()}")
# Out:
# previous_dv0_withoutstraw_sipCAdded.xlsx: original IDs 6 … 62
#    shifted to 6 … 62
# dv0_withoutstraw_sipCAdded.xlsx: original IDs 1 … 14
#    shifted to 64 … 77

# %%
# ------------------------------------------------------------------
# combined DataFrame
# ------------------------------------------------------------------
df_all = pd.concat(dfs, ignore_index=True)
print("\nMerged dataframe shape:", df_all.shape)
print("Global Participant_ID range:", df_all["Participant_ID"].min(),
      "…", df_all["Participant_ID"].max())
# Out:
# Merged dataframe shape: (99996, 82)
# Global Participant_ID range: 6 … 77

# %%
df_all
# Out:
#        Unnamed: 0            Time  Zone_0  Zone_1  Zone_2  Zone_3  Zone_4  \
# 0               0   1747823631000    2162    2155    3941     362     324
# 1               1   1747823631200    2162    2155    3941     362     324
# 2               2   1747823631400    2162    2155    3941     362     324
# 3               3   1747823631600    2162    2155    3941     362     324
# 4               4   1747823631800    2162    2155    3941     362     324
# ...           ...             ...     ...     ...     ...     ...     ...
# 99991       20621   1750719007400    1647    1625    1610    1610    1592
# 99992       20622   1750719007600    1637    1611    1592    1596    1570
# 99993       20623   1750719007800    1607    1607    1592    1595    1568
# 99994       20624   1750719008000    1602    1593    1586    1585    1568
# 99995       20625  17507188911000    1607    1593    1594    1585    1568
#
#        Zone_5  Zone_6  Zone_7  ...  Container_Weight   drink  temp  prev  \
# 0         342    3605    2071  ...              19.8  coke-r     c     0
# 1         342    3605    2071  ...              19.8  coke-r     c     0
# 2         342    3605    2071  ...              19.8  coke-r     c     0
# 3         342    3605    2071  ...              19.8  coke-r     c     0
# 4         342    3605    2071  ...              19.8  coke-r     c     0
# ...       ...     ...     ...  ...               ...     ...   ...   ...
# 99991    1569    1580    1569  ...               7.7   water     n     0
# 99992    1569    1575    1569  ...               7.7   water     n     0
# 99993    1567    1560    1566  ...               7.7   water     n     0
# 99994    1562    1560    1560  ...               7.7   water     n     0
# 99995    1562    1560    1560  ...               7.7   water     n     0
#
#        next  sip_start  sip_end  sip_id   dV  TOTAL_SIP_TIME
# 0         0      False    False       0  0.0               0
# 1         0      False    False       0  0.0               0
# 2         0      False    False       0  0.0               0
# 3         0      False    False       0  0.0               0
# 4         0      False    False       0  0.0               0
# ...     ...        ...      ...     ...  ...             ...
# 99991     0      False    False       5  0.0               0
# 99992     0      False    False       5  0.0               0
# 99993     0      False    False       5  0.0               0
# 99994     0      False    False       5  0.0               0
# 99995     0      False    False       5  0.0               0
#
# [99996 rows x 82 columns]

# %%
df = df_all

# %%
# print("Label stats  (raw, before scaling)")
# print("  min :", y.min())
# print("  #zeros :", (y == 0).sum())
# print("  any negative? ", (y < 0).any())

# %%
# --------------------------------------------------------------------
# user settings
# --------------------------------------------------------------------

BATCH      = 8                                   # 1 = ragged, >1 = padded

# %%
# # ====================================================================
# # 1. load data  ➜  X(list of (T,64)), y(array)   – SKIP zero-volume sips
# # ====================================================================
# df = df[df["Label"] == 1]                        # keep only annotated frames

# feature_cols = df.columns[2:66]
# seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# X, y = [], []
# skip_count = 0

# for _, g in df.groupby(seq_keys, sort=False):
#     dV = float(g[label_col].iloc[0])
#     if dV == 0.0:                                # ← drop empty sip
#         skip_count += 1
#         continue
#     X.append(g[feature_cols].to_numpy(np.float32))   # (T,64)
#     y.append(dV)

# y = np.asarray(y, np.float32)
# X = np.array(X, dtype=object)   # each element is still a (T,64) array
# print(f"Total sips kept : {len(X)}")
# print(f"Zero-volume skipped : {skip_count}")
# print("Label stats  → min:", y.min(), "max:", y.max())

# %%
# # ====================================================================
# # 1. load data  ➜  X(list of (T,64)), y(array) – SKIP zero-volume sips – APPLY AUGMENTATION
# # ====================================================================

# df = df[df["Label"] == 1]                        # keep only annotated frames

# feature_cols = df.columns[2:66]
# seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# # --- Augmentation Functions ---
# def add_gaussian_noise(sip, std_dev=0.01):
#     """Add Gaussian noise to the sip (T, 64)."""
#     noise = np.random.normal(0, std_dev, sip.shape)
#     return sip + noise

# def flip_horizontal(sip):
#     """Flip 8x8 frames horizontally for all time steps in sip (T, 64)."""
#     flipped = []
#     for frame in sip:
#         frame_8x8 = frame.reshape(8, 8)
#         flipped_frame = np.fliplr(frame_8x8).flatten()
#         flipped.append(flipped_frame)
#     return np.array(flipped, dtype=np.float32)

# # --- You control this threshold: sips longer than this will be augmented
# AUGMENT_IF_LONGER_THAN = 15  # You can change this

# # --- Main data list
# X, y = [], []
# skip_count = 0

# for _, g in df.groupby(seq_keys, sort=False):
#     dV = float(g[label_col].iloc[0])
#     if dV == 0.0:
#         skip_count += 1
#         continue

#     sip_frames = g[feature_cols].to_numpy(np.float32)  # shape (T, 64)
#     T = len(sip_frames)

#     X.append(sip_frames)
#     y.append(dV)

#     # Augment only if sip is long
#     if T > AUGMENT_IF_LONGER_THAN:
#         # 1. Add Gaussian noise
#         noisy_sip = add_gaussian_noise(sip_frames)
#         X.append(noisy_sip)
#         y.append(dV)

#         # 2. Flip horizontally
#         flipped_sip = flip_horizontal(sip_frames)
#         X.append(flipped_sip)
#         y.append(dV)
# X = np.array(X, dtype=object)   # each sip is still (T, 64)
# y = np.array(y, dtype=np.float32)

# print(f"Total sips kept (including augmented): {len(X)}")
# print(f"Zero-volume skipped : {skip_count}")
# print("Label stats  → min:", min(y), "max:", max(y))

# %%
# # ====================================================================
# # 1. load data  ➜  X(list of (T,64)), y(array) – SKIP zero-volume sips – APPLY AUGMENTATION
# # ====================================================================


# df = df[df["Label"] == 1]  # keep only annotated frames

# feature_cols = df.columns[2:66]
# seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# # --- Augmentation Functions ---
# def add_gaussian_noise(sip, std_dev=40):
#     """Add Gaussian noise to the sip (T, 64)."""
#     noise = np.random.normal(0, std_dev, sip.shape)
#     return sip + noise

# def flip_horizontal(sip):
#     """Flip 8x8 frames horizontally for all time steps in sip (T, 64)."""
#     flipped = []
#     for frame in sip:
#         frame_8x8 = frame.reshape(8, 8)
#         flipped_frame = np.fliplr(frame_8x8).flatten()
#         flipped.append(flipped_frame)
#     return np.array(flipped, dtype=np.float32)

# # --- Thresholds you control
# AUGMENT_IF_LONGER_THAN = 15           # Regular augmentation if T > this
# MORE_AUGMENT_IF_LONGER_THAN = 20      # Extra augmentation if T > this
# NUM_EXTRA_NOISY_COPIES = 5            # Number of additional noise versions for long sips
# NUM_EXTRA_NOISY_COPIES_2 =7
# MORE_AUGMENT_IF_LONGER_THAN_2= 34
# # --- Main data list
# X, y = [], []
# skip_count = 0

# for _, g in df.groupby(seq_keys, sort=False):
#     dV = float(g[label_col].iloc[0])
#     if dV == 0.0:
#         skip_count += 1
#         continue

#     sip_frames = g[feature_cols].to_numpy(np.float32)  # shape (T, 64)
#     T = len(sip_frames)

#     # Original sip
#     X.append(sip_frames)
#     y.append(dV)

#     # Moderate-length sip → 1 noise + 1 flip
#     if T > AUGMENT_IF_LONGER_THAN:
#         noisy_sip = add_gaussian_noise(sip_frames)
#         X.append(noisy_sip)
#         y.append(dV)

#         flipped_sip = flip_horizontal(sip_frames)
#         X.append(flipped_sip)
#         y.append(dV)

#     # Extra-long sip → multiple noise augmentations
#     if T > MORE_AUGMENT_IF_LONGER_THAN:
#         for _ in range(NUM_EXTRA_NOISY_COPIES):
#             noisy_version = add_gaussian_noise(sip_frames)
#             X.append(noisy_version)
#             y.append(dV)
#     if T > MORE_AUGMENT_IF_LONGER_THAN_2:
#         for _ in range(NUM_EXTRA_NOISY_COPIES_2):
#             noisy_version = add_gaussian_noise(sip_frames)
#             X.append(noisy_version)
#             y.append(dV)        

# # Final conversion to array
# X = np.array(X, dtype=object)   # each sip is still (T, 64)
# y = np.array(y, dtype=np.float32)

# print(f"Total sips kept (including augmented): {len(X)}")
# print(f"Zero-volume skipped : {skip_count}")
# print("Label stats  → min:", min(y), "max:", max(y))

# %%
# ====================================================================
# 1. load data ➜ X (list of (T,64)), y (array), X_aux (structured) – SKIP zero-volume sips – APPLY AUGMENTATION
# ====================================================================

df = df[df["Label"] == 1].copy()  
df['Gender'] = df["Gender"].map({"Male": 1, "Female": 0})

df["Container_Weight"] = df["Container_Weight"].map({
    7.7: 0,
    10.6: 1,
    10.9: 1,  
    12.7: 2,
    19.8: 3,
    359: 4
})
df['temp'] = df ['temp'].map({'h':2, 'c':0, 'n': 1})
feature_cols = df.columns[2:66]
seq_keys, label_col = ["Participant_ID", "sip_id"], "dV"

# --- Augmentation Functions ---
def add_gaussian_noise(sip, std_dev=40):
    noise = np.random.normal(0, std_dev, sip.shape)
    return sip + noise

def flip_horizontal(sip):
    flipped = []
    for frame in sip:
        frame_8x8 = frame.reshape(8, 8)
        flipped_frame = np.fliplr(frame_8x8).flatten()
        flipped.append(flipped_frame)
    return np.array(flipped, dtype=np.float32)

# --- Thresholds
AUGMENT_IF_LONGER_THAN = 15
MORE_AUGMENT_IF_LONGER_THAN = 20
NUM_EXTRA_NOISY_COPIES = 5
MORE_AUGMENT_IF_LONGER_THAN_2 = 34
NUM_EXTRA_NOISY_COPIES_2 = 12

# --- Main data lists
X, y, X_aux = [], [], []
skip_count = 0

for _, g in df.groupby(seq_keys, sort=False):
    dV = float(g[label_col].iloc[0])
    if dV == 0.0:
        skip_count += 1
        continue

    sip_frames = g[feature_cols].to_numpy(np.float32)  # shape (T, 64)
    T = len(sip_frames)

    # Structured features (same for all versions of this sip)
    gender = g["Gender"].iloc[0]
    weight = g["Container_Weight"].iloc[0]
    temp = g["temp"].iloc[0]
    time_steps = T

    aux_features = np.array([gender, weight, temp, time_steps], dtype=np.float32)

    # Original sip
    X.append(sip_frames)
    y.append(dV)
    X_aux.append(aux_features)

    # Augment: Moderate-length → 1 noise + 1 flip
    if T > AUGMENT_IF_LONGER_THAN:
        noisy_sip = add_gaussian_noise(sip_frames)
        X.append(noisy_sip)
        y.append(dV)
        X_aux.append(aux_features)

        flipped_sip = flip_horizontal(sip_frames)
        X.append(flipped_sip)
        y.append(dV)
        X_aux.append(aux_features)

    # Augment: Extra-long sips → multiple noises
    if T > MORE_AUGMENT_IF_LONGER_THAN:
        for _ in range(NUM_EXTRA_NOISY_COPIES):
            noisy_version = add_gaussian_noise(sip_frames)
            X.append(noisy_version)
            y.append(dV)
            X_aux.append(aux_features)

    if T > MORE_AUGMENT_IF_LONGER_THAN_2:
        for _ in range(NUM_EXTRA_NOISY_COPIES_2):
            noisy_version = add_gaussian_noise(sip_frames)
            X.append(noisy_version)
            y.append(dV)
            X_aux.append(aux_features)

# Convert to arrays
X = np.array(X, dtype=object)                # List of (T, 64)
y = np.array(y, dtype=np.float32)            # Labels
X_aux = np.array(X_aux, dtype=np.float32)    # (N, 4)

print(f"Total sips kept (including augmented): {len(X)}")
print(f"Zero-volume skipped : {skip_count}")
print("Label stats  → min:", min(y), "max:", max(y))
print("Auxiliary feature shape →", X_aux.shape)
# Out:
# Total sips kept (including augmented): 1390
# Zero-volume skipped : 2
# Label stats  → min: 1.4691479 max: 160.2
# Auxiliary feature shape → (1390, 4)

# %%
import matplotlib.pyplot as plt

# Get time step lengths for all sips
time_steps = [sip.shape[0] for sip in X]  # X is your final data after augmentation

# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(time_steps, bins=30, alpha=0.7, color='blue')
plt.title('Histogram of Time Steps After Augmentation')
plt.xlabel('Number of Time Steps')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
X[:1]
# Out:
# array([array([[2487.,  165.,  348., ...,  364.,  330., 1817.],
#               [2487.,  165.,  348., ...,  364.,  330., 1817.],
#               [ 265.,  200.,  234., ...,  364.,  352., 1817.],
#               ...,
#               [ 304., 2267., 2300., ...,  331., 1449., 1140.],
#               [ 299., 2267., 2300., ...,  352.,  352., 1151.],
#               [ 295., 2280., 2300., ...,  352., 1449., 1151.]], dtype=float32)],
#       dtype=object)

# %%
print(type(X))          # <class 'numpy.ndarray'>
print(X.shape)          # (number,)

print(type(X[0]))       # <class 'numpy.ndarray'>
print(X[0].shape)       # (rows, columns)
# Out:
# <class 'numpy.ndarray'>
# (1390,)
# <class 'numpy.ndarray'>
# (26, 64)

# %%
# ====================================================================
# 2. shuffle whole sips ➜ 80 / 20 split
# ====================================================================
idx = rng.permutation(len(X))
split1 = int(.64 * len(X))          # 64 % train
split2 = int(.80 * len(X))          # next 16 % val
X_train, y_train, X_aux_train = X[idx[:split1]], y[idx[:split1]], X_aux[idx[:split1]]
X_val,   y_val,   X_aux_val   = X[idx[split1:split2]], y[idx[split1:split2]], X_aux[idx[split1:split2]]
X_test,  y_test,  X_aux_test  = X[idx[split2:]], y[idx[split2:]], X_aux[idx[split2:]]

print(f"Train {len(X_train)} Val {len(X_val)}  Test {len(X_test)}")
# y_train_s = np.log1p(y_train)        # log1p for numerical safety
# y_val_s   = np.log1p(y_val)
# y_test_s  = np.log1p(y_test)
# Out:
# Train 889 Val 223  Test 278

# %%
# Sanity check
for i in range(5):
    print(f"dV: {y_train[i]}, Aux features: {X_aux_train[i]}, Time steps: {len(X_train[i])}")
# Out:
# dV: 39.68254089355469, Aux features: [ 1.  1.  2. 25.], Time steps: 25
# dV: 57.099998474121094, Aux features: [ 1.  0.  1. 17.], Time steps: 17
# dV: 27.32615089416504, Aux features: [ 1.  3.  0. 13.], Time steps: 13
# dV: 26.052888870239258, Aux features: [ 1.  3.  0. 29.], Time steps: 29
# dV: 57.14285659790039, Aux features: [ 1.  3.  0. 24.], Time steps: 24

# %%
# X_train

# %%
# y_train

# %%
# ====================================================================
# 3. column-wise z-score normalisation (fit on training only)
# ====================================================================
mat_train = np.vstack(X_train)          # ⬅ only TRAIN data
mean64 = mat_train.mean(0, keepdims=True)
std64  = mat_train.std(0,  keepdims=True) + 1e-8

norm = lambda seq: (seq - mean64) / std64
X_train = [norm(s) for s in X_train]
X_val   = [norm(s) for s in X_val]
X_test  = [norm(s) for s in X_test]

# # label scaling
# y_max   = y_train.max() or 1.
# y_train_s = y_train / y_max
# y_val_s   = y_val   / y_max
# y_test_s  = y_test  / y_max
y_train_s = y_train 
y_val_s   = y_val   
y_test_s  = y_test

# %%
# X_train

# %%
# # ====================================================================
# # 4. tf.data pipelines
# # ====================================================================
# def generator(xs, ys):
#     for x, y in zip(xs, ys):
#         yield x, y

# output_sig = (
#     tf.TensorSpec((None, 64), tf.float32),
#     tf.TensorSpec((),          tf.float32)
# )

# def make_ds(xs, ys, shuffle=True):
#     ds = tf.data.Dataset.from_generator(lambda: generator(xs, ys),
#                                         output_signature=output_sig)
#     if shuffle:
#         ds = ds.shuffle(len(xs), seed=42)
#     if BATCH == 1:
#         return ds.repeat().batch(1)              # ragged
#     return ds.repeat().padded_batch(             # padded
#         BATCH,
#         padded_shapes=([None, 64], []),
#         padding_values=(0.0, 0.0)
#     )

# train_ds = make_ds(X_train, y_train_s, shuffle=True)
# val_ds   = make_ds(X_val,   y_val_s,   shuffle=False)
# test_ds  = make_ds(X_test,  y_test_s,  shuffle=False)

# %%
# ====================================================================
# 4. tf.data pipelines (with auxiliary features)
# ====================================================================
def generator(xs, x_auxs, ys):
    for x, x_aux, y in zip(xs, x_auxs, ys):
        yield {'tof_sequence': x, 'extra_features': x_aux}, y

output_sig = (
    {
        'tof_sequence': tf.TensorSpec((None, 64), tf.float32),
        'extra_features': tf.TensorSpec((X_aux.shape[1],), tf.float32)
    },
    tf.TensorSpec((), tf.float32)
)

def make_ds(xs, x_auxs, ys, shuffle=True):
    ds = tf.data.Dataset.from_generator(lambda: generator(xs, x_auxs, ys),
                                        output_signature=output_sig)
    if shuffle:
        ds = ds.shuffle(len(xs), seed=42)
    if BATCH == 1:
        return ds.repeat().batch(1)
    return ds.repeat().padded_batch(
        BATCH,
        padded_shapes=(
            {
                'tof_sequence': [None, 64],
                'extra_features': [X_aux.shape[1]],
            },
            []
        ),
        padding_values=(
            {
                'tof_sequence': 0.0,
                'extra_features': 0.0
            },
            0.0
        )
    )

# %%
train_ds = make_ds(X_train, X_aux_train, y_train_s, shuffle=True)
val_ds   = make_ds(X_val,   X_aux_val,   y_val_s,   shuffle=False)
test_ds  = make_ds(X_test,  X_aux_test,  y_test_s,  shuffle=False)

# %%
input_seq = Input(shape=(None, 64), name='tof_sequence')
input_aux = Input(shape=(X_aux.shape[1],), name='extra_features')

# %%
train_ds
# Out:
# <_PaddedBatchDataset element_spec=({'tof_sequence': TensorSpec(shape=(None, None, 64), dtype=tf.float32, name=None), 'extra_features': TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)}, TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
# for batch in train_ds.take(1):
#     x_batch, y_batch = batch
#     print("x_batch shape:", x_batch.shape)
#     print("y_batch shape:", y_batch.shape)
#     print("x_batch:", x_batch.numpy())
#     print("y_batch:", y_batch.numpy())

# %%
# # ====================================================================
# # 5. model  – TCN ➜ Dense(1, softplus) keeps output ≥ 0
# # ====================================================================
# inp = tf.keras.Input(shape=(None, 64))
# x = TCN(nb_filters=128,
#         kernel_size=3,
#         dilations=[1,2,4,8,16,32,64],   # ~64-time-step field
#         dropout_rate=0.1,
#         return_sequences=False)(inp)
# out = tf.keras.layers.Dense(1)(x)          # ← LINEAR output
# model = tf.keras.Model(inp, out)

# model.compile(
#     optimizer=Adagrad(learning_rate=0.01),
#     loss="mae"                             # MAE is more robust
# )
# model.summary()

# steps_per_epoch = len(X_train) // BATCH + (len(X_train) % BATCH > 0)
# val_steps       = len(X_val)   // BATCH + (len(X_val)   % BATCH > 0)
# # weights = (y_train / y_train.max()) ** 0.5  
# cb = tf.keras.callbacks.EarlyStopping(
#          monitor='val_loss', patience=50, restore_best_weights=True)
# model.fit(
#     train_ds,
#     epochs=200,
#     steps_per_epoch=steps_per_epoch,
#     validation_data=val_ds,        # ⬅ use VALIDATION set
#     validation_steps=val_steps,
#     verbose=1,
#     # sample_weight=weights,
#     callbacks=[cb]
# )

# %%
# from tensorflow.keras import Input, Model
# from tensorflow.keras.layers import Dense, Concatenate
# from tcn import TCN

# # Input 1: TOF sequence (T, 64)
# input_seq = Input(shape=(None, 64), name='tof_sequence')

# # Input 2: Dense features (like gender, container weight, temp, etc.)
# input_aux = Input(shape=(n_extra_features,), name='extra_features')

# # TCN block
# x = TCN(nb_filters=128,
#         kernel_size=3,
#         dilations=[1, 2, 4, 8, 16, 32, 64],
#         dropout_rate=0.1,
#         return_sequences=False)(input_seq)

# # Concatenate TCN output with auxiliary features
# combined = Concatenate()([x, input_aux])

# # Dense fusion block
# x = Dense(64, activation='relu')(combined)
# output = Dense(1)(x)

# # Define the full model
# model = Model(inputs=[input_seq, input_aux], outputs=output)
# model.compile(optimizer='Adagrad', loss='mae')
# model.summary()

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tcn import TCN

# === Define Inputs ===
# Input 1: TOF sequence (T, 64)
input_seq = Input(shape=(None, 64), name='tof_sequence')

# Input 2: Auxiliary features (gender, container weight, temp, time_steps)
n_extra_features = X_aux_train.shape[1]
input_aux = Input(shape=(n_extra_features,), name='extra_features')

# === TCN Block ===
x = TCN(
    nb_filters=128,
    kernel_size=3,
    dilations=[1, 2, 4, 8, 16, 32, 64],
    dropout_rate=0.1,
    return_sequences=False
)(input_seq)

# === Combine with Auxiliary Input ===
combined = Concatenate()([x, input_aux])

# === Dense Fusion Layer ===, activation='relu'
x = Dense(64)(combined)
output = Dense(1)(x)

# === Build and Compile Model ===
model = Model(inputs=[input_seq, input_aux], outputs=output)
model.compile(optimizer='Adagrad', loss='mae')
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ tof_sequence        │ (None, None, 64)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tcn (TCN)           │ (None, 128)       │    673,664 │ tof_sequence[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ extra_features      │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 132)       │          0 │ tcn[0][0],        │
# │ (Concatenate)       │                   │            │ extra_features[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         65 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 682,241 (2.60 MB)
#  Trainable params: 682,241 (2.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# === Early stopping callback ===
cb = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# === Epoch step calculation ===
steps_per_epoch = len(X_train) // BATCH + int(len(X_train) % BATCH > 0)
val_steps       = len(X_val)   // BATCH + int(len(X_val) % BATCH > 0)

# === Train the Model ===
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=200,
    steps_per_epoch=steps_per_epoch,
    validation_steps=val_steps,
    callbacks=[cb],
    verbose=1
)
# Out:
# Epoch 1/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 22.6324 - val_loss: 20.1711
# Epoch 2/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 16.5433 - val_loss: 14.4560
# Epoch 3/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 16.1206 - val_loss: 13.6298
# Epoch 4/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 16.9902 - val_loss: 13.2618
# Epoch 5/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 16.1403 - val_loss: 13.2211
# Epoch 6/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 14.6424 - val_loss: 14.4400
# Epoch 7/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 14.1126 - val_loss: 12.2078
# Epoch 8/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 14.3743 - val_loss: 13.0719
# Epoch 9/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 14.4606 - val_loss: 13.3166
# Epoch 10/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 14.2574 - val_loss: 12.1352
# Epoch 11/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 13.2497 - val_loss: 14.2047
# Epoch 12/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 13.0071 - val_loss: 14.1854
# Epoch 13/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 14.6008 - val_loss: 13.3423
# Epoch 14/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.2459 - val_loss: 12.3734
# Epoch 15/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 13.4305 - val_loss: 11.9808
# Epoch 16/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.7938 - val_loss: 12.2599
# Epoch 17/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.5534 - val_loss: 13.0668
# Epoch 18/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 13.2814 - val_loss: 12.6671
# Epoch 19/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 12.9643 - val_loss: 12.0251
# Epoch 20/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.7187 - val_loss: 12.5669
# Epoch 21/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 12.8484 - val_loss: 11.0867
# Epoch 22/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.3172 - val_loss: 11.5911
# Epoch 23/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.2133 - val_loss: 12.6054
# Epoch 24/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.5834 - val_loss: 12.5876
# Epoch 25/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.4183 - val_loss: 11.4455
# Epoch 26/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.8153 - val_loss: 13.0393
# Epoch 27/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 12.3843 - val_loss: 12.1118
# Epoch 28/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.9507 - val_loss: 11.4783
# Epoch 29/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.6802 - val_loss: 11.6400
# Epoch 30/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 12.1956 - val_loss: 11.6057
# Epoch 31/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.6906 - val_loss: 11.8378
# Epoch 32/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.8520 - val_loss: 12.1001
# Epoch 33/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.4323 - val_loss: 11.7365
# Epoch 34/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.8096 - val_loss: 11.5389
# Epoch 35/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.4164 - val_loss: 11.1805
# Epoch 36/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 11.8099 - val_loss: 11.2460
# Epoch 37/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.3941 - val_loss: 12.5456
# Epoch 38/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.0386 - val_loss: 11.8067
# Epoch 39/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.4574 - val_loss: 11.6227
# Epoch 40/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.8066 - val_loss: 11.1805
# Epoch 41/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.2795 - val_loss: 12.2042
# Epoch 42/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.9811 - val_loss: 11.2723
# Epoch 43/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.0023 - val_loss: 12.3854
# Epoch 44/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 11.3128 - val_loss: 11.5720
# Epoch 45/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.5713 - val_loss: 12.6755
# Epoch 46/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.5747 - val_loss: 12.7231
# Epoch 47/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.5139 - val_loss: 12.5211
# Epoch 48/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.3953 - val_loss: 12.6093
# Epoch 49/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.5124 - val_loss: 11.5336
# Epoch 50/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.5926 - val_loss: 12.8048
# Epoch 51/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2059 - val_loss: 12.1473
# Epoch 52/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.4455 - val_loss: 11.8536
# Epoch 53/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.5953 - val_loss: 11.9181
# Epoch 54/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.8843 - val_loss: 12.1113
# Epoch 55/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.7547 - val_loss: 12.1155
# Epoch 56/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.1189 - val_loss: 11.7324
# Epoch 57/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.7849 - val_loss: 11.2685
# Epoch 58/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.9543 - val_loss: 11.3505
# Epoch 59/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.9895 - val_loss: 12.2014
# Epoch 60/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.8084 - val_loss: 12.0537
# Epoch 61/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.0501 - val_loss: 12.1668
# Epoch 62/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.8854 - val_loss: 11.5434
# Epoch 63/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.1385 - val_loss: 12.7292
# Epoch 64/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 11.9053 - val_loss: 11.5851
# Epoch 65/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.2929 - val_loss: 11.4791
# Epoch 66/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.0948 - val_loss: 12.0502
# Epoch 67/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 10.8878 - val_loss: 10.9918
# Epoch 68/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.9421 - val_loss: 11.8982
# Epoch 69/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.6573 - val_loss: 10.8098
# Epoch 70/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.0306 - val_loss: 12.1085
# Epoch 71/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.5687 - val_loss: 11.5907
# Epoch 72/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.3534 - val_loss: 10.5231
# Epoch 73/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.2058 - val_loss: 12.4084
# Epoch 74/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.9568 - val_loss: 11.8839
# Epoch 75/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.5098 - val_loss: 11.6700
# Epoch 76/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2489 - val_loss: 10.8812
# Epoch 77/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.6928 - val_loss: 11.3014
# Epoch 78/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.7845 - val_loss: 11.3310
# Epoch 79/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.6022 - val_loss: 10.9182
# Epoch 80/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2292 - val_loss: 11.3394
# Epoch 81/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.1690 - val_loss: 11.9002
# Epoch 82/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.9885 - val_loss: 11.7511
# Epoch 83/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.8167 - val_loss: 10.8075
# Epoch 84/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.9996 - val_loss: 11.4207
# Epoch 85/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.1340 - val_loss: 10.6763
# Epoch 86/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.4052 - val_loss: 10.7620
# Epoch 87/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.2062 - val_loss: 11.2204
# Epoch 88/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.4757 - val_loss: 10.6987
# Epoch 89/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.1673 - val_loss: 10.1237
# Epoch 90/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.9423 - val_loss: 11.7768
# Epoch 91/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 11.2963 - val_loss: 11.3062
# Epoch 92/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.6114 - val_loss: 10.8990
# Epoch 93/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.5917 - val_loss: 10.9661
# Epoch 94/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.4556 - val_loss: 11.3272
# Epoch 95/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.3925 - val_loss: 10.7165
# Epoch 96/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.8454 - val_loss: 10.5170
# Epoch 97/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.1017 - val_loss: 11.4992
# Epoch 98/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.2463 - val_loss: 10.6371
# Epoch 99/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.3551 - val_loss: 11.5302
# Epoch 100/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.7070 - val_loss: 10.5632
# Epoch 101/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.1123 - val_loss: 10.1796
# Epoch 102/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.3588 - val_loss: 10.6101
# Epoch 103/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.8754 - val_loss: 11.3471
# Epoch 104/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.1435 - val_loss: 10.1385
# Epoch 105/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.7369 - val_loss: 10.8587
# Epoch 106/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.0550 - val_loss: 10.4635
# Epoch 107/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.9824 - val_loss: 10.4887
# Epoch 108/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.5456 - val_loss: 11.2312
# Epoch 109/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.7710 - val_loss: 10.9715
# Epoch 110/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.7519 - val_loss: 10.9967
# Epoch 111/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.7180 - val_loss: 10.8547
# Epoch 112/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.3388 - val_loss: 11.1216
# Epoch 113/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.8621 - val_loss: 10.4116
# Epoch 114/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.4494 - val_loss: 10.7914
# Epoch 115/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.3855 - val_loss: 10.9964
# Epoch 116/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.7294 - val_loss: 10.1233
# Epoch 117/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.1750 - val_loss: 10.9786
# Epoch 118/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.3770 - val_loss: 11.1399
# Epoch 119/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 8.2761 - val_loss: 11.1464
# Epoch 120/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.4043 - val_loss: 10.3763
# Epoch 121/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.2420 - val_loss: 10.2855
# Epoch 122/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.6856 - val_loss: 11.1060
# Epoch 123/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.5504 - val_loss: 10.5449
# Epoch 124/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.0156 - val_loss: 11.3256
# Epoch 125/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.3179 - val_loss: 10.2078
# Epoch 126/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.0837 - val_loss: 10.4333
# Epoch 127/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.4775 - val_loss: 10.6097
# Epoch 128/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.2199 - val_loss: 10.6028
# Epoch 129/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.4600 - val_loss: 10.3823
# Epoch 130/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.8000 - val_loss: 11.3715
# Epoch 131/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.7599 - val_loss: 11.3839
# Epoch 132/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.3296 - val_loss: 10.2996
# Epoch 133/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.8225 - val_loss: 10.2934
# Epoch 134/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.8078 - val_loss: 10.6502
# Epoch 135/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 9.4253 - val_loss: 10.9113
# Epoch 136/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.8028 - val_loss: 10.5054
# Epoch 137/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.3763 - val_loss: 10.5996
# Epoch 138/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.3796 - val_loss: 10.3249
# Epoch 139/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.9686 - val_loss: 10.8826
# Epoch 140/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 8.3557 - val_loss: 10.2382
# Epoch 141/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.7857 - val_loss: 10.3556
# Epoch 142/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 9.2165 - val_loss: 10.3467
# Epoch 143/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.0187 - val_loss: 10.4821
# Epoch 144/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.9404 - val_loss: 10.5889
# Epoch 145/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.1952 - val_loss: 10.0904
# Epoch 146/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.1056 - val_loss: 9.5140
# Epoch 147/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.1007 - val_loss: 10.3700
# Epoch 148/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.8020 - val_loss: 10.0390
# Epoch 149/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.0900 - val_loss: 10.8326
# Epoch 150/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.1579 - val_loss: 11.1622
# Epoch 151/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.3132 - val_loss: 10.6568
# Epoch 152/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.4858 - val_loss: 10.9405
# Epoch 153/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.7450 - val_loss: 10.9502
# Epoch 154/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.2948 - val_loss: 10.7181
# Epoch 155/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.8470 - val_loss: 10.4543
# Epoch 156/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.1470 - val_loss: 9.7507
# Epoch 157/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.9309 - val_loss: 10.7366
# Epoch 158/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.9238 - val_loss: 11.0061
# Epoch 159/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.0123 - val_loss: 10.5567
# Epoch 160/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.0438 - val_loss: 10.6246
# Epoch 161/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.8097 - val_loss: 10.3674
# Epoch 162/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.9775 - val_loss: 10.9864
# Epoch 163/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 7.4347 - val_loss: 10.3781
# Epoch 164/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.5294 - val_loss: 10.9563
# Epoch 165/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.1654 - val_loss: 10.7749
# Epoch 166/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.6467 - val_loss: 10.7794
# Epoch 167/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.1165 - val_loss: 10.5164
# Epoch 168/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.8058 - val_loss: 10.7398
# Epoch 169/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 7.9868 - val_loss: 10.4981
# Epoch 170/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.4911 - val_loss: 10.4026
# Epoch 171/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.8405 - val_loss: 10.4925
# Epoch 172/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.3935 - val_loss: 10.6323
# Epoch 173/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.0699 - val_loss: 10.6160
# Epoch 174/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 8.4373 - val_loss: 10.4091
# Epoch 175/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.9286 - val_loss: 10.2698
# Epoch 176/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.0669 - val_loss: 10.2258
# Epoch 177/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.3778 - val_loss: 9.7091
# Epoch 178/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 7.9623 - val_loss: 10.2826
# Epoch 179/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.8482 - val_loss: 10.4644
# Epoch 180/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.1620 - val_loss: 10.1040
# Epoch 181/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.0833 - val_loss: 10.1834
# Epoch 182/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 8.0378 - val_loss: 10.9106
# Epoch 183/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.1776 - val_loss: 10.5350
# Epoch 184/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.1229 - val_loss: 10.5371
# Epoch 185/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.8565 - val_loss: 10.2358
# Epoch 186/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.1382 - val_loss: 10.1722
# Epoch 187/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.0772 - val_loss: 10.4796
# Epoch 188/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 7.5719 - val_loss: 10.7403
# Epoch 189/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.3231 - val_loss: 10.8286
# Epoch 190/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 8.0682 - val_loss: 10.6900
# Epoch 191/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 7.8506 - val_loss: 10.1233
# Epoch 192/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.5471 - val_loss: 10.3661
# Epoch 193/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 7.5713 - val_loss: 10.0498
# Epoch 194/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 7.9436 - val_loss: 10.7002
# Epoch 195/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 7.3889 - val_loss: 11.0732
# Epoch 196/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 8.0191 - val_loss: 10.1275

# %%
# ====================================================================
# 6. inference on test set (un-scale predictions)
# ====================================================================
# y_pred_s = np.array([model.predict(seq[None, ...], verbose=0)[0, 0]
#                      for seq in X_test])
y_pred_s = np.array([
    model.predict(
        {
            'tof_sequence': seq[None, ...],             # shape (1, T, 64)
            'extra_features': aux[None, ...]            # shape (1, 4)
        },
        verbose=0
    )[0, 0]  # extract scalar from output
    for seq, aux in zip(X_test, X_aux_test)
])

# inverse transform after prediction
# y_pred_s = np.expm1(y_pred_s)
# y_pred   = y_pred_s * y_max
y_pred = y_pred_s
y_mean, y_std = y_train.mean(), y_train.std()
y_train_s = (y_train - y_mean) / y_std
# ...
# y_pred = y_pred_s * y_std + y_mean       # undo scaling

# %%
# ====================================================================
# 7. evaluation
# ====================================================================
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2   = r2_score(y_test, y_pred)

non_zero = y_test != 0
rmspe = (np.sqrt(np.mean(((y_test[non_zero]-y_pred[non_zero]) /
                          y_test[non_zero])**2))*100
         if non_zero.any() else np.nan)

print(f"\nEvaluation on {len(y_test)} test sips")
print(f"  MSE   : {mse:.4f}")
print(f"  RMSE  : {rmse:.4f}")
print(f"  R²    : {r2:.4f}")
print(f"  RMSPE : {rmspe:.2f}%")

comparison_df = pd.DataFrame({"Actual dV": y_test, "Predicted dV": y_pred})
print("\nFirst 50 predictions:")
print(comparison_df.head(50))
# Out:
# Evaluation on 278 test sips
#   MSE   : 333.7986
#   RMSE  : 18.2702
#   R²    : 0.6982
#   RMSPE : 47.93%
#
# First 50 predictions:
#      Actual dV  Predicted dV
# 0    59.700001     17.347549
# 1    19.196865     25.236740
# 2    80.000000     71.034935
# 3    99.206352     87.828415
# 4    41.200001     37.375214
# 5    18.476191     14.676253
# 6    80.699997     66.939140
# 7    16.380953     27.231352
# 8    39.781746     31.867302
# 9    99.206352     89.256248
# 10   14.229249     10.757175
# 11   62.095238     39.831108
# 12   41.200001     36.922001
# 13   12.500000     12.253343
# 14    9.189723     12.981549
# 15   36.630753     24.189232
# 16   78.354553     67.246841
# 17   18.511263     17.171047
# 18   28.000000      8.693141
# 19   22.900000     12.751416
# 20   38.095238     48.227501
# 21   17.361111     17.612476
# 22   32.419197     22.757048
# 23   57.099998     20.078909
# 24   36.000000     15.870266
# 25   21.825397     18.759178
# 26   27.799999      8.388947
# 27   99.206352     89.099373
# 28   14.624506     15.997849
# 29    5.320197      2.663389
# 30   23.114594     18.873009
# 31    9.486166      9.002775
# 32   24.571428     24.819677
# 33   18.750000     13.658979
# 34   58.765915     54.873531
# 35   97.943192     92.426857
# 36   21.841331     12.778636
# 37    5.320197      2.852264
# 38   25.954947     24.258810
# 39  131.699997     98.991119
# 40   59.523811     62.327099
# 41   23.100000     22.532183
# 42   79.365082     73.095421
# 43   18.750000     13.036728
# 44   20.833334      9.905910
# 45   41.200001     38.674660
# 46   54.900002     42.644321
# 47   40.000000     36.958179
# 48   58.700001     56.636040
# 49   22.600000     12.391899

# %%
# ====================================================================
# 8. scatter plot
# ====================================================================
plt.figure(figsize=(7, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
lims = [0, max(y_test.max(), y_pred.max()) * 1.05]
plt.plot(lims, lims, "r--")
plt.xlim(lims); plt.ylim(lims)
plt.xlabel("Actual dV"); plt.ylabel("Predicted dV")
plt.title("TCN – Actual vs. Predicted Drinking Volume")
plt.grid(True); plt.tight_layout(); plt.show()

# %%
# print("First 5 log targets  :", y_train_s[:5])
# print("First 5 raw targets  :", y_train[:5])

# # after one epoch
# raw_pred = np.expm1(model.predict(X_val[:3])[...,0])
# print("First 3 un-scaled predictions:", raw_pred)

# %%
print("train  min / max (ml):", y_train.min(), y_train.max())
print("train_s min / max (log):", y_train_s.min(), y_train_s.max())

# quick expectation check:  ln(1+160) ≈ 5.08
#                           ln(1+  5) ≈ 1.79
# Out:
# train  min / max (ml): 1.4691479 160.2
# train_s min / max (log): -1.3322176 3.5325873

# %% [markdown]
#  # TCN + Dense Feature Fusion
